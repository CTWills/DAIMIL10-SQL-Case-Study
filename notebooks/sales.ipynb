# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_sales = pd.read_excel('../excel_reports/sales_q1.xlsx', index_col=0)

# %%
df_sales.head()
# Out:
#      order_placed  sum_subtotal
# 0  2014/May        5.366675e+06
# 1  2014/March      7.217531e+06
# 2  2014/June       4.900584e+04
# 3  2014/January    4.289818e+06
# 4  2014/February   1.337725e+06

# %%
fig, ax = plt.subplots(figsize=(12,8))
new = sns.lineplot(df_sales, x=df_sales['order_placed'], y=df_sales['sum_subtotal'])
new.set_xticklabels(new.get_xticklabels(), rotation=90, size=8)
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /var/folders/hz/sg34vg_92b77c_hdxw3wkl400000gn/T/ipykernel_51957/2938115861.py:3: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   new.set_xticklabels(new.get_xticklabels(), rotation=90, size=8)
# [Text(0, 0, '2014/May      '),
#  Text(1, 0, '2014/March    '),
#  Text(2, 0, '2014/June     '),
#  Text(3, 0, '2014/January  '),
#  Text(4, 0, '2014/February '),
# ...
